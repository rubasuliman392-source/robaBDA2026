# %% [markdown]
# # Pandas DataFrame Intro
#
# This notebook demonstrates how to work with a Pandas DataFrame.
# We will:
#
# - Load data from `data/symbol_info_3-25.csv` file, randomly sampling 25 rows, and selecting the desired columns.
# - Display general information about the DataFrame.
# - Show the content by position and by column
# - Sort the DataFrame by `Market_cap`.
# - Add a column with the percentage of each `Market_cap` relative to the total market cap.
# - Grouping and aggregation
# - Advanced Sorting and indexing
# - Filtering
# - Operations on non-numerical columns

# %% [markdown]
# ## Loading and Sampling Data
#
# We start by loading a CSV file into a DataFrame, then randomly selecting 25 rows and keeping only the columns we need: `symbol`, `market_cap`, and `sector`.

# %%
# Import the pandas library (the main tool for working with tabular data in Python)
import pandas as pd

# Load all data from the CSV file into a DataFrame
df = pd.read_csv('data/symbol_info_3-25.csv')

# Randomly pick 25 rows from the full dataset
# random_state=42 ensures we always get the same 25 rows (for reproducibility)
df_sample = df.sample(25, random_state=42)

# Keep only the 3 columns we need
df_sample = df_sample[['symbol', 'market_cap', 'sector']]

# Display the result
print('--- Initial Sampled DataFrame ---')
print(df_sample)
print("test")
# Out:
# --- Initial Sampled DataFrame ---
#     symbol    market_cap              sector
# 521    EME   18167234560         Industrials
# 737   WTRG   10683482112           Utilities
# 740   COHR   10647828480          Technology
# 660     SN   12547034112   Consumer Cyclical
# 411    ROL   25068689408   Consumer Cyclical
# 678    BXP   12082990080         Real Estate
# 626    IEX   13923810304         Industrials
# 513      L   18602571776  Financial Services
# 859   CACI    8287675392          Technology
# 136   EQIX   82899656704         Real Estate
# 811    OGE    9103995904           Utilities
# 76     UNP  141880508416         Industrials
# 636    CNA   13326393344  Financial Services
# 973   BBIO    6612871168          Healthcare
# 938   RVMD    7148292608          Healthcare
# 899    GPK    7802572288   Consumer Cyclical
# 280    GLW   41688969216          Technology
# 883   GNRC    7950121472         Industrials
# 761    MTZ   10036755456         Industrials
# 319    SYY   34828255232  Consumer Defensive
# 549    ZTO   16714461184         Industrials
# 174   PYPL   69434900480  Financial Services
# 371   DXCM   29350852608          Healthcare
# 527    KEY   17847687168  Financial Services
# 210    MET   56351207424  Financial Services

# %% [markdown]
# ## Exploring the DataFrame
#
# Before working with data, it is important to understand its structure. We use:
#
# - **`.info()`** — shows column names, data types, and non-null counts
# - **`.describe()`** — gives summary statistics for numerical columns (mean, std, min, max, quartiles)
# - **`.describe(include='str')`** — gives summary statistics for text columns (count, unique values, most frequent)

# %%
# .info() prints a summary: column names, types, and how many non-null values
print('--- DataFrame Info ---')
df_sample.info()

# .describe() gives statistics for numerical columns (count, mean, std, min, max, quartiles)
print('\n--- DataFrame Description (numerical columns) ---')
print(df_sample.describe())

# .describe(include='str') gives statistics for text columns (count, unique values, most frequent)
print('\n--- DataFrame Description (text columns) ---')
print(df_sample.describe(include='str'))
# Out:
# --- DataFrame Info ---
# <class 'pandas.DataFrame'>
# Index: 25 entries, 521 to 210
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   symbol      25 non-null     str
#  1   market_cap  25 non-null     int64
#  2   sector      25 non-null     str
# dtypes: int64(1), str(2)
# memory usage: 800.0 bytes
#
# --- DataFrame Description (numerical columns) ---
#          market_cap
# count  2.500000e+01
# mean   2.731955e+10
# std    3.124412e+10
# min    6.612871e+09
# 25%    1.003676e+10
# 50%    1.392381e+10
# 75%    2.935085e+10
# max    1.418805e+11
#
# --- DataFrame Description (text columns) ---
#        symbol       sector
# count      25           25
# unique     25            8
# top       EME  Industrials
# freq        1            6

# %% [markdown]
# ## Accessing Rows by Position with `.iloc[]`
#
# `.iloc[]` lets you select rows by their **position** (like indexing a Python list). Position `0` is the first row, `-1` is the last, `-2` is the second-to-last, and so on.

# %%
# .iloc[] lets you access rows by their POSITION (like a list index)

# First row (position 0)
print('--- First Element (iloc[0]) ---')
print(df_sample.iloc[0])

# Access a specific column value from the first row
print('\n--- Market Cap of the first Element ---')
print(df_sample.iloc[0]['market_cap'])

# Last row (position -1, just like Python lists)
print('\n--- Last Element (iloc[-1]) ---')
print(df_sample.iloc[-1])

# Second-to-last row
print('\n--- Second-to-Last Element (iloc[-2]) ---')
print(df_sample.iloc[-2])
# Out:
# --- First Element (iloc[0]) ---
# symbol                EME
# market_cap    18167234560
# sector        Industrials
# Name: 521, dtype: object
#
# --- Market Cap of the first Element ---
# 18167234560
#
# --- Last Element (iloc[-1]) ---
# symbol                       MET
# market_cap           56351207424
# sector        Financial Services
# Name: 210, dtype: object
#
# --- Second-to-Last Element (iloc[-2]) ---
# symbol                       KEY
# market_cap           17847687168
# sector        Financial Services
# Name: 527, dtype: object

# %% [markdown]
# ## Sorting a DataFrame
#
# We can sort the rows of a DataFrame by any column using `.sort_values()`. Here we sort by `market_cap` in descending order (largest first).

# %%
# Sort the DataFrame by Market_cap
df_sorted = df_sample.sort_values(by='market_cap', ascending=False)
print('--- DataFrame Sorted by Market_cap ---')
print(df_sorted)
# Out:
# --- DataFrame Sorted by Market_cap ---
#     symbol    market_cap              sector
# 76     UNP  141880508416         Industrials
# 136   EQIX   82899656704         Real Estate
# 174   PYPL   69434900480  Financial Services
# 210    MET   56351207424  Financial Services
# 280    GLW   41688969216          Technology
# 319    SYY   34828255232  Consumer Defensive
# 371   DXCM   29350852608          Healthcare
# 411    ROL   25068689408   Consumer Cyclical
# 513      L   18602571776  Financial Services
# 521    EME   18167234560         Industrials
# 527    KEY   17847687168  Financial Services
# 549    ZTO   16714461184         Industrials
# 626    IEX   13923810304         Industrials
# 636    CNA   13326393344  Financial Services
# 660     SN   12547034112   Consumer Cyclical
# 678    BXP   12082990080         Real Estate
# 737   WTRG   10683482112           Utilities
# 740   COHR   10647828480          Technology
# 761    MTZ   10036755456         Industrials
# 811    OGE    9103995904           Utilities
# 859   CACI    8287675392          Technology
# 883   GNRC    7950121472         Industrials
# 899    GPK    7802572288   Consumer Cyclical
# 938   RVMD    7148292608          Healthcare
# 973   BBIO    6612871168          Healthcare

# %% [markdown]
# ## Operations on a Numerical Column
#
# Pandas provides many built-in functions to summarize a numerical column. Here are the most common ones applied to `market_cap`:
#
# | Function | What it does |
# |----------|-------------|
# | `.sum()` | Total of all values |
# | `.mean()` | Average (sum / count) |
# | `.median()` | Middle value when sorted |
# | `.min()` / `.max()` | Smallest / largest value |
# | `.std()` | Standard deviation (how spread out the values are) |
# | `.var()` | Variance (square of std) |
# | `.quantile([0.25, 0.5, 0.75])` | Values at the 25th, 50th, 75th percentiles |
#
# **Example usage:**
# ```python
# total_market_cap = df_sample['market_cap'].sum()
# average_market_cap = df_sample['market_cap'].mean()
# ```

# %% [markdown]
# ## Adding a Computed Column
#
# We can create a new column based on existing data. Here we compute the **percentage** that each company's market cap represents out of the total market cap of all 25 companies.

# %%
# --- Add a new column: percentage of total market cap ---

# First, compute the total market cap across all 25 companies
total_market_cap = df_sample['market_cap'].sum()

# Divide each company's market_cap by the total and multiply by 100 to get a percentage
df_sample['market_cap_%'] = (df_sample['market_cap'] / total_market_cap) * 100

print('--- DataFrame with Market Cap Percentage ---')
print(df_sample)

# --- Alternative ways to do the same thing (commented out for reference) ---

# Using apply() with a lambda (a one-line anonymous function):
# df_sample['market_cap_%'] = df_sample['market_cap'].apply(lambda x: (x / total_market_cap) * 100)

# Using apply() with a named function:
# def compute_percentage(value):
#     return (value / total_market_cap) * 100
# df_sample['market_cap_%'] = df_sample['market_cap'].apply(compute_percentage)
# Out:
# --- DataFrame with Market Cap Percentage ---
#     symbol    market_cap              sector  market_cap_%
# 521    EME   18167234560         Industrials      2.659961
# 737   WTRG   10683482112           Utilities      1.564225
# 740   COHR   10647828480          Technology      1.559005
# 660     SN   12547034112   Consumer Cyclical      1.837078
# 411    ROL   25068689408   Consumer Cyclical      3.670439
# 678    BXP   12082990080         Real Estate      1.769134
# 626    IEX   13923810304         Industrials      2.038659
# 513      L   18602571776  Financial Services      2.723701
# 859   CACI    8287675392          Technology      1.213442
# 136   EQIX   82899656704         Real Estate     12.137777
# 811    OGE    9103995904           Utilities      1.332964
# 76     UNP  141880508416         Industrials     20.773475
# 636    CNA   13326393344  Financial Services      1.951188
# 973   BBIO    6612871168          Healthcare      0.968225
# 938   RVMD    7148292608          Healthcare      1.046619
# 899    GPK    7802572288   Consumer Cyclical      1.142416
# 280    GLW   41688969216          Technology      6.103902
# 883   GNRC    7950121472         Industrials      1.164019
# 761    MTZ   10036755456         Industrials      1.469534
# 319    SYY   34828255232  Consumer Defensive      5.099389
# 549    ZTO   16714461184         Industrials      2.447253
# 174   PYPL   69434900480  Financial Services     10.166331
# 371   DXCM   29350852608          Healthcare      4.297413
# 527    KEY   17847687168  Financial Services      2.613174
# 210    MET   56351207424  Financial Services      8.250678

# %% [markdown]
# ## Grouping and Aggregation
#
# Sometimes we want to **summarize data by category**. For example: *"What is the total market cap for each sector?"*
#
# The idea is simple — split the data into groups (one per sector), then compute a summary for each group.
#
# We do this in three steps:
#
# 1. **Group** the rows by a column (e.g., `sector`) using `groupby()`
# 2. **Pick** the column we want to summarize (e.g., `market_cap`)
# 3. **Apply** one or more summary functions (`sum`, `mean`, `count`)

# %%
# Step 1: Group the rows by 'sector'
grouped = df_sample.groupby('sector')
print('Step 1 — type:', type(grouped).__name__)
print('Number of groups:', grouped.ngroups)
print('Group sizes:')
print(grouped.size())
print()

# Let's peek inside one group to see what it looks like
print('--- Example: the "Technology" group ---')
print(grouped.get_group('Technology'))
print()

# Step 2: Select the 'market_cap' column from each group
market_cap_by_sector = grouped['market_cap']
print('Step 2 — now we only keep the market_cap values per group:')
for name, values in market_cap_by_sector:
    print(f'  {name}: {values.tolist()}')
print()

# Step 3: Apply summary functions — sum, mean, and count
df_grouped = market_cap_by_sector.agg(['sum', 'mean', 'count'])
print('Step 3 — after agg():')
print(df_grouped)
print()
# Notice: 'sector' is now the index, not a regular column

# reset_index() turns 'sector' back into a regular column
df_grouped = df_grouped.reset_index()
print('After reset_index():')
print(df_grouped)

# NOTE: The 4 steps above can also be written in one line:
# df_grouped = df_sample.groupby('sector')['market_cap'].agg(['sum', 'mean', 'count']).reset_index()
# Out:
# Step 1 — type: DataFrameGroupBy
# Number of groups: 8
# Group sizes:
# sector
# Consumer Cyclical     3
# Consumer Defensive    1
# Financial Services    5
# Healthcare            3
# Industrials           6
# Real Estate           2
# Technology            3
# Utilities             2
# dtype: int64
#
# --- Example: the "Technology" group ---
#     symbol   market_cap      sector  market_cap_% sector_upper  \
# 740   COHR  10647828480  Technology      1.559005   TECHNOLOGY
# 859   CACI   8287675392  Technology      1.213442   TECHNOLOGY
# 280    GLW  41688969216  Technology      6.103902   TECHNOLOGY
#
#     sector_replaced sector_mapped
# 740      Technology          Tech
# 859      Technology          Tech
# 280      Technology          Tech
#
# Step 2 — now we only keep the market_cap values per group:
#   Consumer Cyclical: [12547034112, 25068689408, 7802572288]
#   Consumer Defensive: [34828255232]
#   Financial Services: [18602571776, 13326393344, 69434900480, 17847687168, 56351207424]
#   Healthcare: [6612871168, 7148292608, 29350852608]
#   Industrials: [18167234560, 13923810304, 141880508416, 7950121472, 10036755456, 16714461184]
#   Real Estate: [12082990080, 82899656704]
#   Technology: [10647828480, 8287675392, 41688969216]
#   Utilities: [10683482112, 9103995904]
#
# Step 3 — after agg():
#                              sum          mean  count
# sector
# Consumer Cyclical    45418295808  1.513943e+10      3
# Consumer Defensive   34828255232  3.482826e+10      1
# Financial Services  175562760192  3.511255e+10      5
# Healthcare           43112016384  1.437067e+10      3
# Industrials         208672891392  3.477882e+10      6
# Real Estate          94982646784  4.749132e+10      2
# Technology           60624473088  2.020816e+10      3
# Utilities            19787478016  9.893739e+09      2
#
# After reset_index():
#                sector           sum          mean  count
# 0   Consumer Cyclical   45418295808  1.513943e+10      3
# 1  Consumer Defensive   34828255232  3.482826e+10      1
# 2  Financial Services  175562760192  3.511255e+10      5
# 3          Healthcare   43112016384  1.437067e+10      3
# 4         Industrials  208672891392  3.477882e+10      6
# 5         Real Estate   94982646784  4.749132e+10      2
# 6          Technology   60624473088  2.020816e+10      3
# 7           Utilities   19787478016  9.893739e+09      2

# %% [markdown]
# ## Advanced Sorting and Indexing
#
# By default, a DataFrame uses row numbers (0, 1, 2, ...) as its index. But we can change the index to something more meaningful:
#
# - **`set_index('symbol')`** — use the stock symbol as the row label, so we can look up rows by name (e.g., `df.loc['PYPL']`)
# - **Multi-index** — use *two* columns as a combined index (e.g., `sector` + `symbol`), which organizes the data hierarchically
# - **Sorting by multiple columns** — for example, sort by `sector` alphabetically, and within each sector sort by `market_cap` from largest to smallest

# %%
# --- Using set_index() ---
# Replace the default numeric index with 'symbol', so each row is labeled by its stock ticker
df_indexed = df_sample.set_index('symbol')
print('--- DataFrame with symbol as index ---')
print(df_indexed)

# --- Multi-Index ---
# Use TWO columns as the index: first 'sector', then 'symbol'
# This creates a hierarchical structure: sector > symbol
df_multi_indexed = df_sample.set_index(['sector', 'symbol'])
print('\n--- DataFrame with Multi-Index (sector, symbol) ---')
print(df_multi_indexed)

# --- Sorting by multiple columns ---
# Sort by 'sector' A→Z (ascending=True), then within each sector
# sort by 'market_cap' from largest to smallest (ascending=False)
df_sorted_multi = df_sample.sort_values(
    by=['sector', 'market_cap'],
    ascending=[True, False]
)
print('\n--- DataFrame sorted by sector (A-Z) and market_cap (largest first) ---')
print(df_sorted_multi)
# Out:
# --- DataFrame with symbol as index ---
#           market_cap              sector  market_cap_%
# symbol
# EME      18167234560         Industrials      2.659961
# WTRG     10683482112           Utilities      1.564225
# COHR     10647828480          Technology      1.559005
# SN       12547034112   Consumer Cyclical      1.837078
# ROL      25068689408   Consumer Cyclical      3.670439
# BXP      12082990080         Real Estate      1.769134
# IEX      13923810304         Industrials      2.038659
# L        18602571776  Financial Services      2.723701
# CACI      8287675392          Technology      1.213442
# EQIX     82899656704         Real Estate     12.137777
# OGE       9103995904           Utilities      1.332964
# UNP     141880508416         Industrials     20.773475
# CNA      13326393344  Financial Services      1.951188
# BBIO      6612871168          Healthcare      0.968225
# RVMD      7148292608          Healthcare      1.046619
# GPK       7802572288   Consumer Cyclical      1.142416
# GLW      41688969216          Technology      6.103902
# GNRC      7950121472         Industrials      1.164019
# MTZ      10036755456         Industrials      1.469534
# SYY      34828255232  Consumer Defensive      5.099389
# ZTO      16714461184         Industrials      2.447253
# PYPL     69434900480  Financial Services     10.166331
# DXCM     29350852608          Healthcare      4.297413
# KEY      17847687168  Financial Services      2.613174
# MET      56351207424  Financial Services      8.250678
#
# --- DataFrame with Multi-Index (sector, symbol) ---
#                              market_cap  market_cap_%
# sector             symbol
# Industrials        EME      18167234560      2.659961
# Utilities          WTRG     10683482112      1.564225
# Technology         COHR     10647828480      1.559005
# Consumer Cyclical  SN       12547034112      1.837078
#                    ROL      25068689408      3.670439
# Real Estate        BXP      12082990080      1.769134
# Industrials        IEX      13923810304      2.038659
# Financial Services L        18602571776      2.723701
# Technology         CACI      8287675392      1.213442
# Real Estate        EQIX     82899656704     12.137777
# Utilities          OGE       9103995904      1.332964
# Industrials        UNP     141880508416     20.773475
# Financial Services CNA      13326393344      1.951188
# Healthcare         BBIO      6612871168      0.968225
#                    RVMD      7148292608      1.046619
# Consumer Cyclical  GPK       7802572288      1.142416
# Technology         GLW      41688969216      6.103902
# Industrials        GNRC      7950121472      1.164019
#                    MTZ      10036755456      1.469534
# Consumer Defensive SYY      34828255232      5.099389
# Industrials        ZTO      16714461184      2.447253
# Financial Services PYPL     69434900480     10.166331
# Healthcare         DXCM     29350852608      4.297413
# Financial Services KEY      17847687168      2.613174
#                    MET      56351207424      8.250678
#
# --- DataFrame sorted by sector (A-Z) and market_cap (largest first) ---
#     symbol    market_cap              sector  market_cap_%
# 411    ROL   25068689408   Consumer Cyclical      3.670439
# 660     SN   12547034112   Consumer Cyclical      1.837078
# 899    GPK    7802572288   Consumer Cyclical      1.142416
# 319    SYY   34828255232  Consumer Defensive      5.099389
# 174   PYPL   69434900480  Financial Services     10.166331
# 210    MET   56351207424  Financial Services      8.250678
# 513      L   18602571776  Financial Services      2.723701
# 527    KEY   17847687168  Financial Services      2.613174
# 636    CNA   13326393344  Financial Services      1.951188
# 371   DXCM   29350852608          Healthcare      4.297413
# 938   RVMD    7148292608          Healthcare      1.046619
# 973   BBIO    6612871168          Healthcare      0.968225
# 76     UNP  141880508416         Industrials     20.773475
# 521    EME   18167234560         Industrials      2.659961
# 549    ZTO   16714461184         Industrials      2.447253
# 626    IEX   13923810304         Industrials      2.038659
# 761    MTZ   10036755456         Industrials      1.469534
# 883   GNRC    7950121472         Industrials      1.164019
# 136   EQIX   82899656704         Real Estate     12.137777
# 678    BXP   12082990080         Real Estate      1.769134
# 280    GLW   41688969216          Technology      6.103902
# 740   COHR   10647828480          Technology      1.559005
# 859   CACI    8287675392          Technology      1.213442
# 737   WTRG   10683482112           Utilities      1.564225
# 811    OGE    9103995904           Utilities      1.332964

# %% [markdown]
# ## Filtering Rows with Conditions
#
# We often need to **select only the rows that meet certain criteria**. For example:
# *"Show me only Technology and Financial Services companies with a market cap above average."*
#
# How it works:
# 1. A **condition** like `df['market_cap'] > 100` produces a column of `True`/`False` values (called a **boolean mask**)
# 2. We can combine multiple conditions with `&` (AND) or `|` (OR)
# 3. Passing the mask inside `df[...]` keeps only the rows where the result is `True`

# %%
# First, compute the average market_cap (we need this as our threshold)
average_market_cap = df_sample['market_cap'].mean()
print(f'Average market cap: {average_market_cap:,.0f}')

# Condition 1: market_cap is above average
above_average = df_sample['market_cap'] > average_market_cap

# Condition 2: sector is either "Technology" or "Financial Services"
# isin() checks if each value is in the given list
selected_sectors = df_sample['sector'].isin(['Technology', 'Financial Services'])

# Combine both conditions with & (AND) — both must be True
condition = above_average & selected_sectors

# Apply the filter: keep only rows where condition is True
df_filtered = df_sample[condition]

print('\n--- Filtered: market_cap > average AND sector is Technology or Financial Services ---')
print(df_filtered)
# Out:
# Average market cap: 27,319,552,676
#
# --- Filtered: market_cap > average AND sector is Technology or Financial Services ---
#     symbol   market_cap              sector  market_cap_%
# 280    GLW  41688969216          Technology      6.103902
# 174   PYPL  69434900480  Financial Services     10.166331
# 210    MET  56351207424  Financial Services      8.250678

# %% [markdown]
# ## Operations on Text (String) Columns
#
# Pandas provides string methods via `.str` to work with text data. In this section we will:
#
# - Get the **unique values** in a column and count how often each appears
# - **Convert** text to uppercase
# - **Search** for rows containing a specific word
# - **Replace** specific values with new ones
# - **Map** values to a simplified version using a dictionary

# %%
# --- Getting unique values ---
unique_sectors = df_sample['sector'].unique()
print('--- Unique Sectors ---')
print(unique_sectors)

# --- Counting occurrences ---
# How many companies are in each sector?
sector_counts = df_sample['sector'].value_counts()
print('\n--- Count of Each Sector ---')
print(sector_counts)

# --- Converting text to uppercase ---
# .str gives access to string methods on a whole column
df_sample['sector_upper'] = df_sample['sector'].str.upper()
print('\n--- DataFrame with uppercase sector column added ---')
print(df_sample)

# --- Searching for text inside a column ---
# Find all rows where 'sector' contains the word "tech" (case-insensitive)
df_tech = df_sample[df_sample['sector'].str.contains('tech', case=False, na=False)]
print('\n--- Rows where sector contains "tech" ---')
print(df_tech)

# --- Replacing specific values ---
# Change "Financial Services" to "Finance" everywhere in the column
df_sample['sector_replaced'] = df_sample['sector'].replace({'Financial Services': 'Finance'})
print('\n--- DataFrame with "Financial Services" replaced by "Finance" ---')
print(df_sample)

# --- Mapping values using a dictionary ---
# map() replaces values that match a key; non-matching values become NaN
sector_mapping = {
    'Technology': 'Tech',
    'Financial Services': 'Finance',
    'Industrials': 'Industrial'
}
df_sample['sector_mapped'] = df_sample['sector'].map(sector_mapping)
print('\n--- DataFrame with mapped sector names (unmatched sectors become NaN) ---')
print(df_sample)
# Out:
# --- Unique Sectors ---
# <StringArray>
# [       'Industrials',          'Utilities',         'Technology',
#   'Consumer Cyclical',        'Real Estate', 'Financial Services',
#          'Healthcare', 'Consumer Defensive']
# Length: 8, dtype: str
#
# --- Count of Each Sector ---
# sector
# Industrials           6
# Financial Services    5
# Technology            3
# Consumer Cyclical     3
# Healthcare            3
# Utilities             2
# Real Estate           2
# Consumer Defensive    1
# Name: count, dtype: int64
#
# --- DataFrame with uppercase sector column added ---
#     symbol    market_cap              sector  market_cap_%        sector_upper
# 521    EME   18167234560         Industrials      2.659961         INDUSTRIALS
# 737   WTRG   10683482112           Utilities      1.564225           UTILITIES
# 740   COHR   10647828480          Technology      1.559005          TECHNOLOGY
# 660     SN   12547034112   Consumer Cyclical      1.837078   CONSUMER CYCLICAL
# 411    ROL   25068689408   Consumer Cyclical      3.670439   CONSUMER CYCLICAL
# 678    BXP   12082990080         Real Estate      1.769134         REAL ESTATE
# 626    IEX   13923810304         Industrials      2.038659         INDUSTRIALS
# 513      L   18602571776  Financial Services      2.723701  FINANCIAL SERVICES
# 859   CACI    8287675392          Technology      1.213442          TECHNOLOGY
# 136   EQIX   82899656704         Real Estate     12.137777         REAL ESTATE
# 811    OGE    9103995904           Utilities      1.332964           UTILITIES
# 76     UNP  141880508416         Industrials     20.773475         INDUSTRIALS
# 636    CNA   13326393344  Financial Services      1.951188  FINANCIAL SERVICES
# 973   BBIO    6612871168          Healthcare      0.968225          HEALTHCARE
# 938   RVMD    7148292608          Healthcare      1.046619          HEALTHCARE
# 899    GPK    7802572288   Consumer Cyclical      1.142416   CONSUMER CYCLICAL
# 280    GLW   41688969216          Technology      6.103902          TECHNOLOGY
# 883   GNRC    7950121472         Industrials      1.164019         INDUSTRIALS
# 761    MTZ   10036755456         Industrials      1.469534         INDUSTRIALS
# 319    SYY   34828255232  Consumer Defensive      5.099389  CONSUMER DEFENSIVE
# 549    ZTO   16714461184         Industrials      2.447253         INDUSTRIALS
# 174   PYPL   69434900480  Financial Services     10.166331  FINANCIAL SERVICES
# 371   DXCM   29350852608          Healthcare      4.297413          HEALTHCARE
# 527    KEY   17847687168  Financial Services      2.613174  FINANCIAL SERVICES
# 210    MET   56351207424  Financial Services      8.250678  FINANCIAL SERVICES
#
# --- Rows where sector contains "tech" ---
#     symbol   market_cap      sector  market_cap_% sector_upper
# 740   COHR  10647828480  Technology      1.559005   TECHNOLOGY
# 859   CACI   8287675392  Technology      1.213442   TECHNOLOGY
# 280    GLW  41688969216  Technology      6.103902   TECHNOLOGY
#
# --- DataFrame with "Financial Services" replaced by "Finance" ---
#     symbol    market_cap              sector  market_cap_%  \
# 521    EME   18167234560         Industrials      2.659961
# 737   WTRG   10683482112           Utilities      1.564225
# 740   COHR   10647828480          Technology      1.559005
# 660     SN   12547034112   Consumer Cyclical      1.837078
# 411    ROL   25068689408   Consumer Cyclical      3.670439
# 678    BXP   12082990080         Real Estate      1.769134
# 626    IEX   13923810304         Industrials      2.038659
# 513      L   18602571776  Financial Services      2.723701
# 859   CACI    8287675392          Technology      1.213442
# 136   EQIX   82899656704         Real Estate     12.137777
# 811    OGE    9103995904           Utilities      1.332964
# 76     UNP  141880508416         Industrials     20.773475
# 636    CNA   13326393344  Financial Services      1.951188
# 973   BBIO    6612871168          Healthcare      0.968225
# 938   RVMD    7148292608          Healthcare      1.046619
# 899    GPK    7802572288   Consumer Cyclical      1.142416
# 280    GLW   41688969216          Technology      6.103902
# 883   GNRC    7950121472         Industrials      1.164019
# 761    MTZ   10036755456         Industrials      1.469534
# 319    SYY   34828255232  Consumer Defensive      5.099389
# 549    ZTO   16714461184         Industrials      2.447253
# 174   PYPL   69434900480  Financial Services     10.166331
# 371   DXCM   29350852608          Healthcare      4.297413
# 527    KEY   17847687168  Financial Services      2.613174
# 210    MET   56351207424  Financial Services      8.250678
#
#            sector_upper     sector_replaced
# 521         INDUSTRIALS         Industrials
# 737           UTILITIES           Utilities
# 740          TECHNOLOGY          Technology
# 660   CONSUMER CYCLICAL   Consumer Cyclical
# 411   CONSUMER CYCLICAL   Consumer Cyclical
# 678         REAL ESTATE         Real Estate
# 626         INDUSTRIALS         Industrials
# 513  FINANCIAL SERVICES             Finance
# 859          TECHNOLOGY          Technology
# 136         REAL ESTATE         Real Estate
# 811           UTILITIES           Utilities
# 76          INDUSTRIALS         Industrials
# 636  FINANCIAL SERVICES             Finance
# 973          HEALTHCARE          Healthcare
# 938          HEALTHCARE          Healthcare
# 899   CONSUMER CYCLICAL   Consumer Cyclical
# 280          TECHNOLOGY          Technology
# 883         INDUSTRIALS         Industrials
# 761         INDUSTRIALS         Industrials
# 319  CONSUMER DEFENSIVE  Consumer Defensive
# 549         INDUSTRIALS         Industrials
# 174  FINANCIAL SERVICES             Finance
# 371          HEALTHCARE          Healthcare
# 527  FINANCIAL SERVICES             Finance
# 210  FINANCIAL SERVICES             Finance
#
# --- DataFrame with mapped sector names (unmatched sectors become NaN) ---
#     symbol    market_cap              sector  market_cap_%  \
# 521    EME   18167234560         Industrials      2.659961
# 737   WTRG   10683482112           Utilities      1.564225
# 740   COHR   10647828480          Technology      1.559005
# 660     SN   12547034112   Consumer Cyclical      1.837078
# 411    ROL   25068689408   Consumer Cyclical      3.670439
# 678    BXP   12082990080         Real Estate      1.769134
# 626    IEX   13923810304         Industrials      2.038659
# 513      L   18602571776  Financial Services      2.723701
# 859   CACI    8287675392          Technology      1.213442
# 136   EQIX   82899656704         Real Estate     12.137777
# 811    OGE    9103995904           Utilities      1.332964
# 76     UNP  141880508416         Industrials     20.773475
# 636    CNA   13326393344  Financial Services      1.951188
# 973   BBIO    6612871168          Healthcare      0.968225
# 938   RVMD    7148292608          Healthcare      1.046619
# 899    GPK    7802572288   Consumer Cyclical      1.142416
# 280    GLW   41688969216          Technology      6.103902
# 883   GNRC    7950121472         Industrials      1.164019
# 761    MTZ   10036755456         Industrials      1.469534
# 319    SYY   34828255232  Consumer Defensive      5.099389
# 549    ZTO   16714461184         Industrials      2.447253
# 174   PYPL   69434900480  Financial Services     10.166331
# 371   DXCM   29350852608          Healthcare      4.297413
# 527    KEY   17847687168  Financial Services      2.613174
# 210    MET   56351207424  Financial Services      8.250678
#
#            sector_upper     sector_replaced sector_mapped
# 521         INDUSTRIALS         Industrials    Industrial
# 737           UTILITIES           Utilities           NaN
# 740          TECHNOLOGY          Technology          Tech
# 660   CONSUMER CYCLICAL   Consumer Cyclical           NaN
# 411   CONSUMER CYCLICAL   Consumer Cyclical           NaN
# 678         REAL ESTATE         Real Estate           NaN
# 626         INDUSTRIALS         Industrials    Industrial
# 513  FINANCIAL SERVICES             Finance       Finance
# 859          TECHNOLOGY          Technology          Tech
# 136         REAL ESTATE         Real Estate           NaN
# 811           UTILITIES           Utilities           NaN
# 76          INDUSTRIALS         Industrials    Industrial
# 636  FINANCIAL SERVICES             Finance       Finance
# 973          HEALTHCARE          Healthcare           NaN
# 938          HEALTHCARE          Healthcare           NaN
# 899   CONSUMER CYCLICAL   Consumer Cyclical           NaN
# 280          TECHNOLOGY          Technology          Tech
# 883         INDUSTRIALS         Industrials    Industrial
# 761         INDUSTRIALS         Industrials    Industrial
# 319  CONSUMER DEFENSIVE  Consumer Defensive           NaN
# 549         INDUSTRIALS         Industrials    Industrial
# 174  FINANCIAL SERVICES             Finance       Finance
# 371          HEALTHCARE          Healthcare           NaN
# 527  FINANCIAL SERVICES             Finance       Finance
# 210  FINANCIAL SERVICES             Finance       Finance
